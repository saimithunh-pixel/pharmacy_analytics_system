# %%
import pandas as pd
import sqlite3

# %%
df = pd.read_csv("data1cleaned_pharmacy_data.csv")
print(df.head())
# Out:
#   Medicine_ID Medicine_Name   Category  Stock_quantity  Price_per_unit  \
# 0      MED001  Azithromycin  Injection             373          363.88
# 1      MED002     Ibuprofen  Injection              12          512.00
# 2      MED003     Vitamin C     Tablet             131          213.90
# 3      MED004    Cetirizine      Syrup             467          421.11
# 4      MED005  Azithromycin    Capsule             229          242.00
#
#              Supplier_Name Expiry_Date Purchase_Date  Reorder_Level  \
# 0  Healthcare Distributors  2027-07-28    05-12-2026           23.0
# 1              Apollo Meds  2026-10-20    12-09-2025           98.0
# 2  Healthcare Distributors  2026-01-12    29-10-2025           98.0
# 3        Medlife Suppliers  2027-04-06    01-12-2026           74.0
# 4               Abc Pharma  2027-07-28    26-07-2027           68.0
#
#   Prescription_Required
# 0                    NO
# 1                  YES
# 2                  YES
# 3                    NO
# 4                    NO

# %%
connection = sqlite3.connect("pharmacy_database.db")

# %%
inventory_table = df[[
    'Medicine_Name',
    'Category',
    'Stock_Quantity',
    'Price_per_unit',
    'Reorder_Level',
    'Storage_Location'
]]

inventory_table.to_sql(
    'Inventory',
    connection,
    if_exists='replace',
    index=False
)

print("Inventory table created successfully!")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 inventory_table = df[[
#       2     'Medicine_Name',
#       3     'Category',
#       4     'Stock_Quantity',
#
# File ~\AppData\Roaming\Python\Python314\site-packages\pandas\core\frame.py:4384, in DataFrame.__getitem__(self, key)
#    4380                 indexer = [indexer]
#    4381         else:
#    4382             if is_iterator(key):
#    4383                 key = list(key)
# -> 4384             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4385
#    4386         # take() does not accept boolean indexers
#    4387         if getattr(indexer, "dtype", None) == bool:
#
# File ~\AppData\Roaming\Python\Python314\site-packages\pandas\core\indexes\base.py:6302, in Index._get_indexer_strict(self, key, axis_name)
#    6299 else:
#    6300     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6302 self._raise_if_missing(keyarr, indexer, axis_name)
#    6304 keyarr = self.take(indexer)
#    6305 if isinstance(key, Index):
#    6306     # GH 42790 - Preserve name from an Index
#
# File ~\AppData\Roaming\Python\Python314\site-packages\pandas\core\indexes\base.py:6355, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6352     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6354 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 6355 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['Stock_Quantity', 'Storage_Location'] not in index"

# %%
print(df.columns.tolist())
# Out:
# ['Medicine_ID', 'Medicine_Name', 'Category', 'Stock_quantity', 'Price_per_unit', 'Supplier_Name', 'Expiry_Date', 'Purchase_Date', 'Reorder_Level', 'Prescription_Required']

# %%
inventory_table = df[[
    'Medicine_Name',
    'Category',
    'Stock_Quantity',
    'Price_per_unit',
    'Reorder_Level',
    'Storage_Location'
]]

inventory_table.to_sql(
    'Inventory',
    connection,
    if_exists='replace',
    index=False
)

print("Inventory table created successfully!")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 inventory_table = df[[
#       2     'Medicine_Name',
#       3     'Category',
#       4     'Stock_Quantity',
#
# File ~\AppData\Roaming\Python\Python314\site-packages\pandas\core\frame.py:4384, in DataFrame.__getitem__(self, key)
#    4380                 indexer = [indexer]
#    4381         else:
#    4382             if is_iterator(key):
#    4383                 key = list(key)
# -> 4384             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4385
#    4386         # take() does not accept boolean indexers
#    4387         if getattr(indexer, "dtype", None) == bool:
#
# File ~\AppData\Roaming\Python\Python314\site-packages\pandas\core\indexes\base.py:6302, in Index._get_indexer_strict(self, key, axis_name)
#    6299 else:
#    6300     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6302 self._raise_if_missing(keyarr, indexer, axis_name)
#    6304 keyarr = self.take(indexer)
#    6305 if isinstance(key, Index):
#    6306     # GH 42790 - Preserve name from an Index
#
# File ~\AppData\Roaming\Python\Python314\site-packages\pandas\core\indexes\base.py:6355, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6352     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6354 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 6355 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['Stock_Quantity', 'Storage_Location'] not in index"

# %%
inventory_table = df[[
    'Medicine_Name',
    'Category',
    'Stock_quantity',
    'Price_per_unit',
    'Reorder_Level',
    'Storage_Location'
]]

inventory_table.to_sql(
    'Inventory',
    connection,
    if_exists='replace',
    index=False
)

print("Inventory table created successfully!")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 inventory_table = df[[
#       2     'Medicine_Name',
#       3     'Category',
#       4     'Stock_quantity',
#
# File ~\AppData\Roaming\Python\Python314\site-packages\pandas\core\frame.py:4384, in DataFrame.__getitem__(self, key)
#    4380                 indexer = [indexer]
#    4381         else:
#    4382             if is_iterator(key):
#    4383                 key = list(key)
# -> 4384             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4385
#    4386         # take() does not accept boolean indexers
#    4387         if getattr(indexer, "dtype", None) == bool:
#
# File ~\AppData\Roaming\Python\Python314\site-packages\pandas\core\indexes\base.py:6302, in Index._get_indexer_strict(self, key, axis_name)
#    6299 else:
#    6300     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6302 self._raise_if_missing(keyarr, indexer, axis_name)
#    6304 keyarr = self.take(indexer)
#    6305 if isinstance(key, Index):
#    6306     # GH 42790 - Preserve name from an Index
#
# File ~\AppData\Roaming\Python\Python314\site-packages\pandas\core\indexes\base.py:6355, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6352     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6354 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 6355 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['Storage_Location'] not in index"

# %%
inventory_table = df[[
    'Medicine_Name',
    'Category',
    'Stock_quantity',
    'Price_per_unit',
    'Reorder_Level'
]]

inventory_table.to_sql(
    'Inventory',
    connection,
    if_exists='replace',
    index=False
)

print("Inventory table created successfully!")
# Out:
# Inventory table created successfully!

# %%
inventory_table = df[[
    'Medicine_Name',
    'Category',
    'Stock_Quantity',
    'Price_per_unit',
    'Reorder_Level',
    'Storage_Location'
]]

inventory_table.to_sql(
    'Inventory',
    connection,
    if_exists='replace',
    index=False
)

print("Inventory table created successfully!")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 inventory_table = df[[
#       2     'Medicine_Name',
#       3     'Category',
#       4     'Stock_Quantity',
#
# File ~\AppData\Roaming\Python\Python314\site-packages\pandas\core\frame.py:4384, in DataFrame.__getitem__(self, key)
#    4380                 indexer = [indexer]
#    4381         else:
#    4382             if is_iterator(key):
#    4383                 key = list(key)
# -> 4384             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4385
#    4386         # take() does not accept boolean indexers
#    4387         if getattr(indexer, "dtype", None) == bool:
#
# File ~\AppData\Roaming\Python\Python314\site-packages\pandas\core\indexes\base.py:6302, in Index._get_indexer_strict(self, key, axis_name)
#    6299 else:
#    6300     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6302 self._raise_if_missing(keyarr, indexer, axis_name)
#    6304 keyarr = self.take(indexer)
#    6305 if isinstance(key, Index):
#    6306     # GH 42790 - Preserve name from an Index
#
# File ~\AppData\Roaming\Python\Python314\site-packages\pandas\core\indexes\base.py:6355, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6352     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6354 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 6355 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['Stock_Quantity', 'Storage_Location'] not in index"

# %%
df = pd.read_csv("cleaned_pharmacy_data.csv")
print(df.head())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 df = pd.read_csv("cleaned_pharmacy_data.csv")
#       2 print(df.head())
#
# File ~\AppData\Roaming\Python\Python314\site-packages\pandas\io\parsers\readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     861 kwds_defaults = _refine_defaults_read(
#     862     dialect,
#     863     delimiter,
#    (...)    869     dtype_backend=dtype_backend,
#     870 )
#     871 kwds.update(kwds_defaults)
# --> 873 return _read(filepath_or_buffer, kwds)
#
# File ~\AppData\Roaming\Python\Python314\site-packages\pandas\io\parsers\readers.py:300, in _read(filepath_or_buffer, kwds)
#     297 _validate_names(kwds.get("names", None))
#     299 # Create the parser.
# --> 300 parser = TextFileReader(filepath_or_buffer, **kwds)
#     302 if chunksize or iterator:
#     303     return parser
#
# File ~\AppData\Roaming\Python\Python314\site-packages\pandas\io\parsers\readers.py:1645, in TextFileReader.__init__(self, f, engine, **kwds)
#    1642     self.options["has_index_names"] = kwds["has_index_names"]
#    1644 self.handles: IOHandles | None = None
# -> 1645 self._engine = self._make_engine(f, self.engine)
#
# File ~\AppData\Roaming\Python\Python314\site-packages\pandas\io\parsers\readers.py:1904, in TextFileReader._make_engine(self, f, engine)
#    1902     if "b" not in mode:
#    1903         mode += "b"
# -> 1904 self.handles = get_handle(
#    1905     f,
#    1906     mode,
#    1907     encoding=self.options.get("encoding", None),
#    1908     compression=self.options.get("compression", None),
#    1909     memory_map=self.options.get("memory_map", False),
#    1910     is_text=is_text,
#    1911     errors=self.options.get("encoding_errors", "strict"),
#    1912     storage_options=self.options.get("storage_options", None),
#    1913 )
#    1914 assert self.handles is not None
#    1915 f = self.handles.handle
#
# File ~\AppData\Roaming\Python\Python314\site-packages\pandas\io\common.py:930, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     925 elif isinstance(handle, str):
#     926     # Check whether the filename is to be opened in binary mode.
#     927     # Binary mode does not support 'encoding' and 'newline'.
#     928     if ioargs.encoding and "b" not in ioargs.mode:
#     929         # Encoding
# --> 930         handle = open(
#     931             handle,
#     932             ioargs.mode,
#     933             encoding=ioargs.encoding,
#     934             errors=errors,
#     935             newline="",
#     936         )
#     937     else:
#     938         # Binary mode
#     939         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'cleaned_pharmacy_data.csv'

# %%
df = pd.read_csv("data1/cleaned_pharmacy_data.csv")
print(df.head())
# Out:
#   Medicine_ID Medicine_Name   Category  Stock_Quantity  Price_per_unit  \
# 0      MED001  Azithromycin  Injection           373.0          363.88
# 1      MED002     Ibuprofen  Injection            12.0          512.00
# 2      MED003     Vitamin C     Tablet           131.0          213.90
# 3      MED004    Cetirizine      Syrup           467.0          421.11
# 4      MED005  Azithromycin    Capsule           229.0          242.00
#
#              Supplier_Name Expiry_Date Purchase_Date  Reorder_Level  \
# 0  Healthcare Distributors  28-07-2027    05-12-2026           23.0
# 1              Apollo Meds  20-10-2026    12-09-2025           98.0
# 2  Healthcare Distributors  12-01-2026    29-10-2025           98.0
# 3        Medlife Suppliers  06-04-2027    01-12-2026           74.0
# 4               Abc Pharma  28-07-2027    26-07-2027           68.0
#
#   Prescription_Required  Units_Sold Storage_Location
# 0                    NO       299.0           Rack C
# 1                  YES         53.0          Shelf 1
# 2                  YES         73.0     Cold Storage
# 3                    NO       151.0           Rack A
# 4                    NO       247.0           Rack A

# %%
inventory_table = df[[
    'Medicine_Name',
    'Category',
    'Stock_Quantity',
    'Price_per_unit',
    'Reorder_Level',
    'Storage_Location'
]]

inventory_table.to_sql(
    'Inventory',
    connection,
    if_exists='replace',
    index=False
)

print("Inventory table created successfully!")
# Out:
# Inventory table created successfully!

# %%
prescription_table = df[[
    'Medicine_Name',
    'Prescription_Required',
    'Units_Sold'
]]

prescription_table.to_sql(
    'Prescriptions',
    connection,
    if_exists='replace',
    index=False
)

print("Prescription table created successfully!")
# Out:
# Prescription table created successfully!

# %%
supplier_table = df[[
    'Supplier_Name',
    'Medicine_Name',
    'Stock_Quantity',
    'Price_per_unit'
]]

supplier_table.to_sql(
    'Supplier_Records',
    connection,
    if_exists='replace',
    index=False
)

print("Supplier table created successfully!")
# Out:
# Supplier table created successfully!

# %%
expiry_table = df[[
    'Medicine_Name',
    'Expiry_Date'
]]

expiry_table.to_sql(
    'Expiry_Logs',
    connection,
    if_exists='replace',
    index=False
)

print("Expiry logs table created successfully!")
# Out:
# Expiry logs table created successfully!

# %%
query1 = "SELECT * FROM Inventory"

inventory_data = pd.read_sql(query1, connection)

print(inventory_data.head())
# Out:
#   Medicine_Name   Category  Stock_Quantity  Price_per_unit  Reorder_Level  \
# 0  Azithromycin  Injection           373.0          363.88           23.0
# 1     Ibuprofen  Injection            12.0          512.00           98.0
# 2     Vitamin C     Tablet           131.0          213.90           98.0
# 3    Cetirizine      Syrup           467.0          421.11           74.0
# 4  Azithromycin    Capsule           229.0          242.00           68.0
#
#   Storage_Location
# 0           Rack C
# 1          Shelf 1
# 2     Cold Storage
# 3           Rack A
# 4           Rack A

# %%
query2 = "SELECT * FROM Supplier_Records"

supplier_data = pd.read_sql(query2, connection)

print(supplier_data.head())
# Out:
#              Supplier_Name Medicine_Name  Stock_Quantity  Price_per_unit
# 0  Healthcare Distributors  Azithromycin           373.0          363.88
# 1              Apollo Meds     Ibuprofen            12.0          512.00
# 2  Healthcare Distributors     Vitamin C           131.0          213.90
# 3        Medlife Suppliers    Cetirizine           467.0          421.11
# 4               Abc Pharma  Azithromycin           229.0          242.00

# %%
connection.close()

# %%
import pandas as pd
import sqlite3

df = pd.read_csv("cleaned_pharmacy_data.csv")

connection = sqlite3.connect("pharmacy_database.db")

inventory_table = df[[
    'Medicine_Name',
    'Category',
    'Stock_Quantity',
    'Price_per_unit',
    'Reorder_Level',
    'Storage_Location'
]]

inventory_table.to_sql(
    'Inventory',
    connection,
    if_exists='replace',
    index=False
)

prescription_table = df[[
    'Medicine_Name',
    'Prescription_Required',
    'Units_Sold'
]]

prescription_table.to_sql(
    'Prescriptions',
    connection,
    if_exists='replace',
    index=False
)

supplier_table = df[[
    'Supplier_Name',
    'Medicine_Name',
    'Stock_Quantity',
    'Price_per_unit'
]]

supplier_table.to_sql(
    'Supplier_Records',
    connection,
    if_exists='replace',
    index=False
)

expiry_table = df[[
    'Medicine_Name',
    'Expiry_Date'
]]

expiry_table.to_sql(
    'Expiry_Logs',
    connection,
    if_exists='replace',
    index=False
)

print("All database tables created successfully!")

query1 = "SELECT * FROM Inventory"

inventory_data = pd.read_sql(query1, connection)

print("\nINVENTORY TABLE")
print(inventory_data.head())

query2 = "SELECT * FROM Supplier_Records"

supplier_data = pd.read_sql(query2, connection)

print("\nSUPPLIER RECORDS TABLE")
print(supplier_data.head())

connection.close()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[19], line 4
#       1 import pandas as pd
#       2 import sqlite3
#       3
# ----> 4 df = pd.read_csv("cleaned_pharmacy_data.csv")
#       5
#       6 connection = sqlite3.connect("pharmacy_database.db")
#       7
#
# File ~\AppData\Roaming\Python\Python314\site-packages\pandas\io\parsers\readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     861 kwds_defaults = _refine_defaults_read(
#     862     dialect,
#     863     delimiter,
#    (...)    869     dtype_backend=dtype_backend,
#     870 )
#     871 kwds.update(kwds_defaults)
# --> 873 return _read(filepath_or_buffer, kwds)
#
# File ~\AppData\Roaming\Python\Python314\site-packages\pandas\io\parsers\readers.py:300, in _read(filepath_or_buffer, kwds)
#     297 _validate_names(kwds.get("names", None))
#     299 # Create the parser.
# --> 300 parser = TextFileReader(filepath_or_buffer, **kwds)
#     302 if chunksize or iterator:
#     303     return parser
#
# File ~\AppData\Roaming\Python\Python314\site-packages\pandas\io\parsers\readers.py:1645, in TextFileReader.__init__(self, f, engine, **kwds)
#    1642     self.options["has_index_names"] = kwds["has_index_names"]
#    1644 self.handles: IOHandles | None = None
# -> 1645 self._engine = self._make_engine(f, self.engine)
#
# File ~\AppData\Roaming\Python\Python314\site-packages\pandas\io\parsers\readers.py:1904, in TextFileReader._make_engine(self, f, engine)
#    1902     if "b" not in mode:
#    1903         mode += "b"
# -> 1904 self.handles = get_handle(
#    1905     f,
#    1906     mode,
#    1907     encoding=self.options.get("encoding", None),
#    1908     compression=self.options.get("compression", None),
#    1909     memory_map=self.options.get("memory_map", False),
#    1910     is_text=is_text,
#    1911     errors=self.options.get("encoding_errors", "strict"),
#    1912     storage_options=self.options.get("storage_options", None),
#    1913 )
#    1914 assert self.handles is not None
#    1915 f = self.handles.handle
#
# File ~\AppData\Roaming\Python\Python314\site-packages\pandas\io\common.py:930, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     925 elif isinstance(handle, str):
#     926     # Check whether the filename is to be opened in binary mode.
#     927     # Binary mode does not support 'encoding' and 'newline'.
#     928     if ioargs.encoding and "b" not in ioargs.mode:
#     929         # Encoding
# --> 930         handle = open(
#     931             handle,
#     932             ioargs.mode,
#     933             encoding=ioargs.encoding,
#     934             errors=errors,
#     935             newline="",
#     936         )
#     937     else:
#     938         # Binary mode
#     939         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'cleaned_pharmacy_data.csv'

# %%
import pandas as pd
import sqlite3

df = pd.read_csv("data1/cleaned_pharmacy_data.csv")

connection = sqlite3.connect("pharmacy_database.db")

inventory_table = df[[
    'Medicine_Name',
    'Category',
    'Stock_Quantity',
    'Price_per_unit',
    'Reorder_Level',
    'Storage_Location'
]]

inventory_table.to_sql(
    'Inventory',
    connection,
    if_exists='replace',
    index=False
)

prescription_table = df[[
    'Medicine_Name',
    'Prescription_Required',
    'Units_Sold'
]]

prescription_table.to_sql(
    'Prescriptions',
    connection,
    if_exists='replace',
    index=False
)

supplier_table = df[[
    'Supplier_Name',
    'Medicine_Name',
    'Stock_Quantity',
    'Price_per_unit'
]]

supplier_table.to_sql(
    'Supplier_Records',
    connection,
    if_exists='replace',
    index=False
)

expiry_table = df[[
    'Medicine_Name',
    'Expiry_Date'
]]

expiry_table.to_sql(
    'Expiry_Logs',
    connection,
    if_exists='replace',
    index=False
)

print("All database tables created successfully!")

query1 = "SELECT * FROM Inventory"

inventory_data = pd.read_sql(query1, connection)

print("\nINVENTORY TABLE")
print(inventory_data.head())

query2 = "SELECT * FROM Supplier_Records"

supplier_data = pd.read_sql(query2, connection)

print("\nSUPPLIER RECORDS TABLE")
print(supplier_data.head())

connection.close()
# Out:
# All database tables created successfully!
#
# INVENTORY TABLE
#   Medicine_Name   Category  Stock_Quantity  Price_per_unit  Reorder_Level  \
# 0  Azithromycin  Injection           373.0          363.88           23.0
# 1     Ibuprofen  Injection            12.0          512.00           98.0
# 2     Vitamin C     Tablet           131.0          213.90           98.0
# 3    Cetirizine      Syrup           467.0          421.11           74.0
# 4  Azithromycin    Capsule           229.0          242.00           68.0
#
#   Storage_Location
# 0           Rack C
# 1          Shelf 1
# 2     Cold Storage
# 3           Rack A
# 4           Rack A
#
# SUPPLIER RECORDS TABLE
#              Supplier_Name Medicine_Name  Stock_Quantity  Price_per_unit
# 0  Healthcare Distributors  Azithromycin           373.0          363.88
# 1              Apollo Meds     Ibuprofen            12.0          512.00
# 2  Healthcare Distributors     Vitamin C           131.0          213.90
# 3        Medlife Suppliers    Cetirizine           467.0          421.11
# 4               Abc Pharma  Azithromycin           229.0          242.00
